# %%
import hashlib

input_text = "I like shiny things. but i'll marry you with paper rings. aa ha. thats right. you are the one i want"
input_lines = input_text.split(". ")
input_lines = list(map(str.encode, input_lines))

hash_object = list(map(hashlib.sha1, input_lines))
hash_values = list(map(type(hash_object[0]).hexdigest, hash_object))

def merkel(hash_values):
  
  counter = 0
  root = ''
  
  for i in range(len(hash_values)):
    if i == counter**2:
      root += hash_values[i-1]
      counter += 1
    else:
      root += hash_values[i]
    return root

merkel(hash_values)
# Out:
# '8e6e1096dbdb1aeede7dc623c0d3329db5e46942'

# %% [markdown]
# To implement Merkel Tree

# %%
import hashlib

input_text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Aenean posuere augue sit amet tellus mollis, vel pretium massa aliquam. Nulla elementum nulla odio, mollis ornare arcu pulvinar id. Donec consequat odio quis felis dictum, eu molestie est cursus. Aenean tincidunt dictum sem tincidunt iaculis. Etiam lacinia sapien nec mi ultricies, pellentesque luctus tellus pretium. Nullam non felis nec justo mattis consectetur. Vestibulum porttitor, nisi nec laoreet efficitur, ante ante convallis leo, vel imperdiet massa enim eu ante. Nullam vitae libero sem. Maecenas sodales mauris ligula, hendrerit sagittis dolor sollicitudin vitae."
input_lines = input_text.split(". ")
input_lines = list(map(str.encode, input_lines))

hash_object = list(map(hashlib.sha1, input_lines))
hash_values = list(map(type(hash_object[0]).hexdigest, hash_object))

def merkel(hash_values):
  
  counter = 0
  root = ''
  
  for i in range(len(hash_values)):
    if i == counter**2:
      root += hash_values[i-1]
      counter += 1
    else:
      root += hash_values[i]
  return root

print(merkel(hash_values))
# Out:
# ...

# %%
import hashlib

# %%
input_text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Aenean posuere augue sit amet tellus mollis, vel pretium massa aliquam. Nulla elementum nulla odio, mollis ornare arcu pulvinar id. Donec consequat odio quis felis dictum, eu molestie est cursus. Aenean tincidunt dictum sem tincidunt iaculis. Etiam lacinia sapien nec mi ultricies, pellentesque luctus tellus pretium. Nullam non felis nec justo mattis consectetur. Vestibulum porttitor, nisi nec laoreet efficitur, ante ante convallis leo, vel imperdiet massa enim eu ante. Nullam vitae libero sem. Maecenas sodales mauris ligula, hendrerit sagittis dolor sollicitudin vitae."
input_lines = input_text.split(". ")
input_lines = list(map(str.encode, input_lines))

hash_object = list(map(hashlib.sha1,input_lines))
hash_values = list(map(type(hash_object[0]).hexdigest, hash_object))

# %%
def merkel(hash_values):
  counter = 0
  merkel_root = ''

  for i in range(len(hash_values)):
    if i == counter**2:
      merkel_root += hash_values[i-1]
      counter+=1
    else:
      merkel_root += hash_values[i]
  return merkel_root

# %%
print(merkel(hash_values))
# Out:
# ...
